# %%
import pandas as pd

# %%
def load_corpus(path):
  lines = [line.strip() for line in open(path)]
  return lines
lines = load_corpus('/content/sample_data/data/TRAIN_FILE.TXT')

# %%
def clean_str(text):
  text = text.replace('<e1>', ' _e11_ ')
  text = text.replace('</e1>', ' _e12_ ')
  text = text.replace('<e2>', ' _e21_ ')
  text = text.replace('</e2>', ' _e22_ ')
  return text.split("\t")[1].strip().lstrip('\"').rstrip('\"')

# %%
check_relations = {"Cause-Effect" : True,
                   "Component-Whole" : True,
                   "Entity-Origin" : True,
                   "Content-Container" : True,
                   "Other" : True}

# %%
def data_preprocessing(lines):
  data = []
  relations = []
  for i in range(0, len(lines), 4):
    sentence = lines[i]
    label = lines[i+1]
    relation = label.strip()
    if("(" in label.strip()):
      relation = label.strip()[:-7]
      if(relation not in check_relations):
        relation = "Other"
      data.append([clean_str(sentence).strip(), relation])
    if(relation not in relations):
      relations.append(relation)
  return data, relations      
data, relations = data_preprocessing(lines)
print(data)
# Out:
# [['The system as described above has its greatest application in an arrayed  _e11_ configuration _e12_  of antenna  _e21_ elements _e22_ .', 'Component-Whole'], ['The  _e11_ author _e12_  of a keygen uses a  _e21_ disassembler _e22_  to look at the raw assembly code.', 'Other'], ['The  _e11_ student _e12_   _e21_ association _e22_  is the voice of the undergraduate student population of the State University of New York at Buffalo.', 'Other'], ['The current view is that the chronic  _e11_ inflammation _e12_  in the distal part of the stomach caused by Helicobacter pylori  _e21_ infection _e22_  results in an increased acid production from the non-infected upper corpus region of the stomach.', 'Cause-Effect'], ['_e11_ People _e12_  have been moving back into  _e21_ downtown _e22_ .', 'Other'], ['The  _e11_ lawsonite _e12_  was contained in a  _e21_ platinum crucible _e22_  and the counter-weight was a plastic crucible with metal pieces.', 'Content-Container'], ['The solute was placed inside a beaker and 5 mL of the  _e11_ solvent _e12_  was pipetted into a 25 mL glass  _e21_ flask _e22_  for each trial.', 'Other'], ["The fifty  _e11_ essays _e12_  collected in this  _e21_ volume _e22_  testify to most of the prominent themes from Professor Quispel's scholarly career.", 'Other'], ['The Pulitzer Committee issues an official  _e11_ citation _e12_  explaining the  _e21_ reasons _e22_  for the award.', 'Other'], ['The  _e11_ burst _e12_  has been caused by water hammer  _e21_ pressure _e22_ .', 'Cause-Effect'], ['Even commercial  _e11_ networks _e12_  have moved into  _e21_ high-definition broadcast _e22_ .', 'Other'], ['It was a friendly  _e11_ call _e12_  to remind them about the  _e21_ bill _e22_  and make sure they have a copy of the invoice.', 'Other'], ['Texas-born  _e11_ virtuoso _e12_  finds harmony, sophistication in Appalachian  _e21_ instrument _e22_ .', 'Other'], ["The  _e11_ factory _e12_ 's products have included flower pots, Finnish rooster-whistles, pans,  _e21_ trays _e22_ , tea pots, ash trays and air moisturisers.", 'Other'], ['The girl showed a photo of apple  _e11_ tree _e12_   _e21_ blossom _e22_  on a fruit tree in the Central Valley.', 'Component-Whole'], ['They tried an assault of their own an hour later, with two columns of sixteen tanks backed by a  _e11_ battalion _e12_  of Panzer  _e21_ grenadiers _e22_ .', 'Other'], ['Their  _e11_ knowledge _e12_  of the power and rank symbols of the Continental empires was gained from the numerous Germanic  _e21_ recruits _e22_  in the Roman army, and from the Roman practice of enfeoffing various Germanic warrior groups with land in the imperial provinces.', 'Entity-Origin'], ['She soon had a  _e11_ stable _e12_  of her own rescued  _e21_ hounds _e22_ .', 'Other'], ['The  _e11_ singer _e12_ , who performed three of the nominated songs, also caused a  _e21_ commotion _e22_  on the red carpet.', 'Cause-Effect'], ['Poor hygiene controls, reports of a  _e11_ brace _e12_  of gamey  _e21_ grouse _e22_  and what looked like a skinned fox all amounted to a pie that was unfit for human consumption.', 'Other'], ['_e11_ Suicide _e12_  is one of the leading causes of  _e21_ death _e22_  among pre-adolescents and teens, and victims of bullying are at an increased risk for committing suicide.', 'Cause-Effect'], ['This  _e11_ article _e12_  gives details on 2004 in  _e21_ music _e22_  in the United Kingdom, including the official charts from that year.', 'Other'], ['We have therefore taken the initiative to convene the first international open  _e11_ meeting _e12_  dedicated solely to  _e21_ rural history _e22_ .', 'Other'], ['The  _e11_ timer _e12_  of the  _e21_ device _e22_  automatically eliminates wasted "standby power" consumption by automatically turn off electronics plugged into the "auto off" outlets.', 'Component-Whole'], ['Bob Parks made a similar  _e11_ offer _e12_  in a  _e21_ phone call _e22_  made earlier this week.', 'Other'], ['He had chest pains and  _e11_ headaches  ...

# %%
relation_dict = {}
label_dict = {}
for i in range(len(relations)):
  relation_dict[relations[i]] = i
  label_dict[i] = relations[i]
print(relation_dict)
# Out:
# {'Component-Whole': 0, 'Other': 1, 'Cause-Effect': 2, 'Content-Container': 3, 'Entity-Origin': 4}

# %%
data = []
for i in range(0, len(lines), 4):
  sentence = lines[i]
  label = lines[i+1]
  relation = label.strip()
  if("(" in label.strip()):
    relation = label.strip()[:-7]
    if(relation not in check_relations):
      relation = "Other"
  data.append([clean_str(sentence).strip(), relation_dict[relation]])

# %%
df = pd.DataFrame(data, columns=['sentences', 'labels'])

# %%
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
n_most_common_words = 20000 # vocabulary size
max_len = 100
def sentence_tokenizer(df):
  # Initialization
  tokenizer = Tokenizer(num_words=n_most_common_words, filters='!"#$%&()*+,-./:;=?@[]^_`{|}~', lower=True)
  # Fit and transformation
  tokenizer.fit_on_texts(df['sentences'].values)
  sequences = tokenizer.texts_to_sequences(df['sentences'].values)
  word_index = tokenizer.word_index
  print('Found %s unique tokens.' % len(word_index))
  # Padding
  X = pad_sequences(sequences, maxlen=max_len, padding= 'post')
  return X
X = sentence_tokenizer(df)
print(X)
# Out:
# Found 19551 unique tokens.
# [[   1   92   21 ...    0    0    0]
#  [   1    2  447 ...    0    0    0]
#  [   1    2  228 ...    0    0    0]
#  ...
#  [  10  765   23 ...    0    0    0]
#  [   1 1016    8 ...    0    0    0]
#  [   1    2 1566 ...    0    0    0]]

# %%
from keras.utils.np_utils import to_categorical
labels = to_categorical(df['labels'], num_classes=len(df.labels.unique()))
X_train, X_test, y_train, y_test = train_test_split(X , labels, test_size=0.20, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, Embedding

embedding_size = 300
model = Sequential()
model.add(Embedding(n_most_common_words, embedding_size, input_length=X.shape[1]))
model.add(Bidirectional(LSTM(128, dropout=0.7, recurrent_dropout=0.7)))
model.add(Dense(labels.shape[1], activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 300)          6000000
#
#  bidirectional (Bidirectiona  (None, 256)              439296
#  l)
#
#  dense (Dense)               (None, 5)                 1285
#
# =================================================================
# Total params: 6,440,581
# Trainable params: 6,440,581
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 40/40 [==============================] - 83s 2s/step - loss: 1.2322 - acc: 0.5924 - val_loss: 1.1438 - val_acc: 0.6031
# Epoch 2/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.9483 - acc: 0.6510 - val_loss: 0.8850 - val_acc: 0.6836
# Epoch 3/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.6380 - acc: 0.7717 - val_loss: 0.8110 - val_acc: 0.7195
# Epoch 4/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.4281 - acc: 0.8584 - val_loss: 0.8780 - val_acc: 0.7422
# Epoch 5/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.2528 - acc: 0.9246 - val_loss: 0.8992 - val_acc: 0.7492
# Epoch 6/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.1378 - acc: 0.9580 - val_loss: 1.0059 - val_acc: 0.7453
# Epoch 7/10
# 40/40 [==============================] - 85s 2s/step - loss: 0.0939 - acc: 0.9727 - val_loss: 1.1102 - val_acc: 0.7570
# Epoch 8/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.0602 - acc: 0.9818 - val_loss: 1.1523 - val_acc: 0.7523
# Epoch 9/10
# 40/40 [==============================] - 79s 2s/step - loss: 0.0465 - acc: 0.9881 - val_loss: 1.0310 - val_acc: 0.7563
# Epoch 10/10
# 40/40 [==============================] - 78s 2s/step - loss: 0.0293 - acc: 0.9945 - val_loss: 1.2474 - val_acc: 0.7648

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

y_test_gold = []

index, true_label = np.where(y_test == 1)

# %%
def number_to_category(label):
  if(label in label_dict):
    return label_dict[label]
  else:
    return "Other"

# %%
prediction_probas = model.predict(X_test) 
predictions = [np.argmax(pred) for pred in prediction_probas]

print(confusion_matrix(true_label, predictions))
print(classification_report(true_label, predictions, digits=3))
# Out:
# [[ 95  87   2   7   6]
#  [ 50 823  12  13  40]
#  [  6  36 138   0  19]
#  [  5  37   1  85   2]
#  [  4  54   2   2  74]]
#               precision    recall  f1-score   support
#
#            0      0.594     0.482     0.532       197
#            1      0.794     0.877     0.833       938
#            2      0.890     0.693     0.780       199
#            3      0.794     0.654     0.717       130
#            4      0.525     0.544     0.534       136
#
#     accuracy                          0.759      1600
#    macro avg      0.719     0.650     0.679      1600
# weighted avg      0.758     0.759     0.755      1600

# %%
lines = load_corpus('/content/sample_data/data/TEST_FILE.txt')
data = []
for sentence in lines:
  data.append([clean_str(sentence).strip(), relation_dict[relation]])
# print(data)  
df = pd.DataFrame(data, columns=['sentences', 'relation'])
X = sentence_tokenizer(df)

prediction_probas = model.predict(X) 
predictions = [np.argmax(pred) for pred in prediction_probas]
# Out:
# Found 10608 unique tokens.

# %%
print(len(predictions))
print(len(df['sentences']))
for i, row in df.iterrows():
    print('index: ', i, 'sentence: ', row['sentences'], 'relation: ', number_to_category(predictions[i]))
    if i == 50:
      break
# Out:
# 1
# 1
# index:  0 sentence:  He is  _e11_ intelligent _e12_ . He is a  _e21_ good _e22_  chess player. relation:  Other

# %%
lines = ['8003	"The <e1>workpackage</e1> comprise of the following <e2>tasks</e2>: Task 2.1 Compilation of long term data sets."']
data = []
for sentence in lines:
  data.append([clean_str(sentence).strip(), relation_dict[relation]])
df = pd.DataFrame(data, columns=['sentences', 'relation'])
X = sentence_tokenizer(df)

prediction_probas = model.predict(X) 
predictions = [np.argmax(pred) for pred in prediction_probas]

for i, row in df.iterrows():
    print('index: ', i, 'sentence: ', row['sentences'], 'relation: ', number_to_category(predictions[i]))
# Out:
# Found 18 unique tokens.
# index:  0 sentence:  The  _e11_ workpackage _e12_  comprise of the following  _e21_ tasks _e22_ : Task 2.1 Compilation of long term data sets. relation:  Entity-Origin
